# %% [markdown]
# # Women’s Clothing E-Commerce Dataset (real commercial data)
# from https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews/home
#
# Questions:
# 1) The top 10 best selling clothing & top 20 best selling and rated clothing?
#
# 2) The effect of age on the cloth selling and reviews.
#
# 3) WordCloud from the reviews.
#
# 4) What kinds of Reviews have more positive feedback counts?
#
# 3) Sizing & Price

# %%
#nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package tagsets to
# [nltk_data]     /Users/hanzhang/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# True

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %%
# for interactive plots 
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.20.5
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
data = pd.read_csv('Womens Clothing E-Commerce Reviews.csv',index_col=False)
numeric_features = data.select_dtypes(include=[np.number])
#print(numeric_features.columns)
categorical_features = data.select_dtypes(include=[np.object])
#print(categorical_features.columns)
data.tail()
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# 23484  Very cute dress, perfect for summer parties an...
# 23485                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
# ...

# %%
#data.columns
print('Clothing ID (unique)',len(data['Clothing ID'].unique()))
print('Total size of data',data.shape)
# Out:
# Clothing ID (unique) 1206
# Total size of data (23486, 11)

# %% [markdown]
# ### The total num of rows of the data is 23486 on 1206 unique clothings.

# %% [markdown]
# ## Check and fill the missing data

# %%
pd.isnull(data).sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %% [markdown]
# A lot of NaNs in the Title and Review Columns.

# %% [markdown]
# Fill the missing Division, Department, Class Name based on Clothing ID.

# %%
#Fill the missing data by looking at the other same key words clothes 
#review[review.str.contains("socks")]
#review[review.str.contains("leg warmer")]
#data.iloc[18014]

# %%
data[data['Clothing ID'] == 136 ]=data[data['Clothing ID'] == 136].fillna({'Division Name':'Initmates',\
                                         'Department Name':'Initmate','Class Name':'Legwear'})
data[data['Clothing ID'] == 72 ]=data[data['Clothing ID'] == 72].fillna({'Division Name':'Initmates',\
                                         'Department Name':'Initmate','Class Name':'Legwear'})
data[data['Clothing ID'] == 152 ]=data[data['Clothing ID'] == 152].fillna({'Division Name':'Initmates',\
                                         'Department Name':'Initmate','Class Name':'Legwear'})
data[data['Clothing ID'] == 184 ]=data[data['Clothing ID'] == 184].fillna({'Division Name':'Initmates',\
                                         'Department Name':'Initmate','Class Name':'Legwear'})
data[data['Clothing ID'] == 492]=data[data['Clothing ID'] == 492].fillna({'Division Name':'Initmates',\
                                         'Department Name':'Initmate','Class Name':'Lounge'})
data[data['Clothing ID'] == 772]=data[data['Clothing ID'] == 772].fillna({'Division Name':'General',\
                                         'Department Name':'Tops','Class Name':'Knits'})
data[data['Clothing ID'] == 665 ]=data[data['Clothing ID'] == 665].fillna({'Division Name':'Initmates',\
                                         'Department Name':'Initmate','Class Name':'Intimates'})

# %%
# create a new feature Text Length
data['Text Length'] = data['Review Text'][data['Review Text'].notnull()].apply(len)

# %% [markdown]
# ### Analysis

# %%
# numeric columns
#sb.pairplot(data[["Clothing ID","Age", "Rating","Recommended IND"]],size = 2 ,kind ='scatter',diag_kind='kde')
data_nms=data[["Age", "Rating","Recommended IND",'Positive Feedback Count','Text Length']]
sns.heatmap(data_nms.corr(),annot=True)

# %%
#data[data['Division Name'].isnull()]
# Rating 
g=sns.countplot(x='Rating',data=data)
data.groupby(['Rating']).count().Age/len(data['Rating'])
# Out:
# Rating
# 1    0.035851
# 2    0.066635
# 3    0.122243
# 4    0.216171
# 5    0.559099
# Name: Age, dtype: float64

# %%
data.groupby(['Recommended IND']).count().Age/len(data['Recommended IND'])
# Out:
# Recommended IND
# 0    0.177638
# 1    0.822362
# Name: Age, dtype: float64

# %% [markdown]
# 55.9% of rating is 5, 82% of IND is recommened, very good

# %%
#data['Rating'].hist(by=data['Recommended IND'],figsize=(12,4))
# 3 is a division if the rating is below 3 most likely not recommended. 
sns.countplot(x='Rating',data=data, hue='Recommended IND')

# %% [markdown]
# Rating and recommended is correlated. Make sense.
# 3 is a division if the rating is below 3 most likely not recommended.

# %%
f, ax = plt.subplots(1, 3, figsize=(12, 4))
# age of customers 
sns.distplot((data["Age"]), color="b", label="Skewness : %.2f  Kurtosis : %.2f"\
                %((data['Age']).skew(), (data['Age']).kurt()),bins=25,ax=ax[0],kde=False)
ax[0].legend(loc="best")

# positive feedback count log10()
pfc=(data["Positive Feedback Count"].map(lambda i: np.log(i) if i > 0 else 0))
sns.distplot(pfc, \
               color="b", label="Skewness : %.2f  Kurtosis : %.2f"\
                %((pfc).skew(), (pfc).kurt() ),bins=25,ax=ax[1],kde=False)
ax[1].legend(loc="best")
plt.tight_layout()
# text length
tl=data["Text Length"][data["Text Length"].notnull()]
sns.distplot((tl), color="b", label="Skewness : %.2f  Kurtosis : %.2f"\
                %((tl).skew(), (tl).kurt()),bins=10,ax=ax[2],kde=False)
ax[2].legend(loc="best")

# %%
sns.boxplot(x='Rating',y='Age',data=data,hue='Recommended IND')

# %% [markdown]
# It seems Age does not affect the rating very much. But we do notice that even in rating 1, some people still recommend
# the product (16 cases) while in rating 5, still no recommendation (25 cases). Saved two data frames. And these two cases, age of customers is about 50, older than the normal case. (maybe they are confused with the system?)

# %%
r1_recom=data[(data['Rating'] == 1) & (data['Recommended IND'] == 1)]
r5_no_recom=data[(data['Rating'] == 5) & (data['Recommended IND'] == 0)]

# %%
sns.barplot(x='Rating',y='Positive Feedback Count',data=data)

# %% [markdown]
# ### Division Department Class

# %%
print(data['Division Name'].unique())
print(data['Department Name'].unique())
print(data['Class Name'].unique())
# Out:
# ['Initmates' 'General' 'General Petite']
# ['Intimate' 'Dresses' 'Bottoms' 'Tops' 'Jackets' 'Trend' 'Initmate']
# ['Intimates' 'Dresses' 'Pants' 'Blouses' 'Knits' 'Outerwear' 'Lounge'
#  'Sweaters' 'Skirts' 'Fine gauge' 'Sleep' 'Jackets' 'Swim' 'Trend' 'Jeans'
#  'Legwear' 'Shorts' 'Layering' 'Casual bottoms' 'Chemises']

# %%
f, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.countplot(x='Division Name',data=data,ax=ax[0],order=data['Division Name'].value_counts().index)
data['Division Name'].value_counts()
sns.countplot(x='Department Name',data=data,ax=ax[1],order=data['Department Name'].value_counts().index)

# %% [markdown]
# General sells more.

# %%
plt.subplots(figsize=(8, 5))
sns.countplot(y='Class Name', data=data,order=data['Class Name'].value_counts().index)

# %%
ID_rating_count=data.groupby(['Clothing ID']).agg(['mean','count'])['Positive Feedback Count']

# %%
#plt.plot(ID_rating_count['mean'],ID_rating_count['count'],'bo')
num = 20
#f, ax = plt.subplots(1, 1, figsize=(8, 5))
sns.countplot(y=data['Clothing ID'], \
              order=data['Clothing ID'].value_counts().iloc[:num].index)

#sns.barplot(y=data.groupby(['Clothing ID']).mean().Rating[
#             data['Clothing ID'].value_counts().iloc[:num].index],\
#            x=data['Clothing ID'].value_counts().iloc[:num].index,\
#            order=data['Clothing ID'].value_counts().iloc[:num].index,ax=ax[1])

# %% [markdown]
#  Top 20 best selling products (averaged rating also high (above 4)) Top 10 Best Selling Products (counts) [936, 868, 895, 1110, 829, 872, 1081, 1094, 862, 1078]
# The best selling is 1078 dress

# %%
#data[["Division Name", "Rating"]].groupby(['Division Name']).mean()
#ID_rating=data.groupby(['Clothing ID','Rating']).size().reset_index(name="counts")
#ID_rating_mean=ID_rating.drop_duplicates().groupby(['Clothing ID']).sum()

# %%
f, ax = plt.subplots(1, 2, figsize=(15, 6))
fsize = 13
sns.heatmap(pd.crosstab(data['Department Name'], data['Division Name']),
            annot=True, linewidths=.5, ax=ax[0], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})

sns.heatmap(pd.crosstab(data['Class Name'], data['Department Name']),
            annot=True, linewidths=.5, ax=ax[1], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})

# %%
#data.groupby(['Rating','Recommended IND']).mean()['Positive Feedback Count']
f, ax = plt.subplots(1, 3, figsize=(18, 7))
fsize = 13
sns.heatmap(pd.crosstab(data['Division Name'],data['Rating']),
            annot=True, linewidths=.5, ax=ax[0], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})

sns.heatmap(pd.crosstab( data['Department Name'],data['Rating']),
            annot=True, linewidths=.5, ax=ax[1], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})


sns.heatmap(pd.crosstab(data['Class Name'],data['Rating']),
            annot=True, linewidths=.5, fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'},ax=ax[2])

# %%
#data.groupby(['Rating','Recommended IND']).mean()['Positive Feedback Count']
f, ax = plt.subplots(1, 3, figsize=(18, 7))
fsize = 13
sns.heatmap(pd.crosstab(data['Division Name'],data['Rating'],normalize = 'index'),
            annot=True, linewidths=.5, ax=ax[0], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})

sns.heatmap(pd.crosstab( data['Department Name'],data['Rating'],normalize = 'index'),
            annot=True, linewidths=.5, ax=ax[1], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})


sns.heatmap(pd.crosstab(data['Class Name'],data['Rating'],normalize = 'index'),
            annot=True, linewidths=.5, fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'},ax=ax[2])

# %% [markdown]
# General, General Petite have similar rating percent. Intimate sells very well. Dresses sell very well.

# %% [markdown]
# # Customer Review (Natural Language Processing)

# %%
#nltk.download_shell()
#review[4]
# dealing with the string 
import string
review=data['Review Text'][data['Review Text'].notnull()]
title=data['Title'][data['Title'].notnull()]

# %%
g=sns.FacetGrid(data,col='Rating')
g.map(plt.hist,'Text Length')

# %% [markdown]
# About the same shape, high rating has a little bit longer text. The limit of review seems to be 500.

# %%
# remove it/have/has etc 
from nltk.corpus import stopwords
stopwords_en = nltk.corpus.stopwords.words('english')
#clean_review = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
a=review.str.lower()#.str.replace(r'\W+', ' ')#.str.cat(sep=' ')
a[1]
# Out:
# 'love this dress!  it\'s sooo pretty.  i happened to find it in a store, and i\'m glad i did bc i never would have ordered it online bc it\'s petite.  i bought a petite and am 5\'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.'

# %%
nltk.help.upenn_tagset('VB')
# Out:
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...

# %%
words = nltk.tokenize.word_tokenize(a[1]) 
nltk.pos_tag(words)
# Out:
# [('love', 'VB'),
#  ('this', 'DT'),
#  ('dress', 'NN'),
#  ('!', '.'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('sooo', 'JJ'),
#  ('pretty', 'RB'),
#  ('.', '.'),
#  ('i', 'NN'),
#  ('happened', 'VBD'),
#  ('to', 'TO'),
#  ('find', 'VB'),
#  ('it', 'PRP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('store', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('i', 'JJ'),
#  ("'m", 'VBP'),
#  ('glad', 'JJ'),
#  ('i', 'NN'),
#  ('did', 'VBD'),
#  ('bc', 'NN'),
#  ('i', 'NN'),
#  ('never', 'RB'),
#  ('would', 'MD'),
#  ('have', 'VB'),
#  ('ordered', 'VBN'),
#  ('it', 'PRP'),
#  ('online', 'PRP'),
#  ('bc', 'VBZ'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('petite', 'JJ'),
#  ('.', '.'),
#  ('i', 'VB'),
#  ('bought', 'VBD'),
#  ('a', 'DT'),
#  ('petite', 'NN'),
#  ('and', 'CC'),
#  ('am', 'VBP'),
#  ("5'8", 'CD'),
#  ("''", "''"),
#  ('.', '.'),
#  ('i', 'VB'),
#  ('love', 'VBP'),
#  ('the', 'DT'),
#  ('length', 'NN'),
#  ('on', 'IN'),
#  ('me-', 'JJ'),
#  ('hits', 'NNS'),
#  ('just', 'RB'),
# ...

# %%
#review
def word_freq(s):
    txt = s.str.lower().str.replace(r'\W+', ' ').str.cat(sep=' ')  # \W+ replace non-character and non-digital values
                                                                # cat concatenate strings with ' ' no line any more 
                                                                # becomes a big list 
    words = nltk.tokenize.word_tokenize(txt)  
    words_dist = nltk.FreqDist(w for w in words if w not in stopwords_en\
                                       and w not in string.punctuation and not w.isdigit()) 
    return words_dist

# %%
words_dist_review=word_freq(review)  # review 
words_dist_title=word_freq(title)    # title

# %%
from wordcloud import WordCloud
f, ax = plt.subplots(1, 2, figsize=(22, 10))
#plt.figure( figsize=(20,10) )
wordcloud = WordCloud(background_color='black',width=2000, height=1000).generate_from_frequencies(words_dist_title)#' '.join(rslt['Word']))
ax[0].imshow(wordcloud)
ax[0].axis("off")
#plt.show()

wordcloud = WordCloud(background_color='black',width=2000, height=1000).generate_from_frequencies(words_dist_review)#' '.join(rslt['Word']))
ax[1].imshow(wordcloud)
ax[1].axis("off")
#plt.show()
# Out:
# (-0.5, 1999.5, 999.5, -0.5)

# %% [markdown]
# Dress is the popular product of the company. We notice size, which is important for the online selling.
# Analyze size (small, large, fit) and price later.

# %%
# look at low rating and not recommended reviews
ratinglow = data[(data['Rating'] <=3) & (data['Recommended IND'] ==0)]['Review Text']

# %%
#word_freq(ratinglow).most_common(100)

# %%
#print(word_freq(r1_recom['Review Text']).most_common(60))

# %%
#rating1 = data[data['Recommended IND'] == 0]['Review Text']
print(word_freq(r1_recom['Review Text']).most_common(20))

#r1_recom
# Out:
# [('size', 7), ('love', 6), ('dress', 6), ('small', 5), ('tried', 4), ('one', 4), ('jacket', 3), ('top', 3), ('back', 3), ('soft', 3), ('store', 3), ('band', 3), ('wear', 3), ('match', 3), ('order', 3), ('purchase', 3), ('fit', 3), ('probably', 3), ('beautiful', 2), ('got', 2)]

# %%
print(word_freq(r5_no_recom['Review Text']).most_common(20))
# Out:
# [('size', 11), ('like', 9), ('length', 8), ('fit', 7), ('great', 7), ('one', 6), ('comfortable', 6), ('quality', 6), ('wear', 6), ('perfect', 6), ('looks', 6), ('bought', 6), ('love', 5), ('little', 5), ('petite', 5), ('ordered', 5), ('color', 5), ('dress', 5), ('perfectly', 5), ('much', 5)]

# %% [markdown]
# I checked two cases: 1) rating is very low but still recommened 2) rating is very high but not recommended.
# The word that tops is about size.

# %%
review_1078=data[data['Clothing ID'] == 1078]
review_1078['Review Text'].head()
# Out:
# 69     I really wanted this to work. alas, it had a s...
# 90     I love cute summer dresses and this one, espec...
# 117    This is the perfect summer dress. it can be dr...
# 467    Nice fit and flare style, not clingy at all. i...
# 470    When i first opened this dress and tried it on...
# Name: Review Text, dtype: object

# %%
f, ax = plt.subplots(1, 2, figsize=(9, 4))
fsize = 13
sns.heatmap(pd.crosstab(review_1078['Rating'], review_1078['Division Name'],normalize = 'columns'),
            annot=True, linewidths=.5, ax=ax[0], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})
#plt.show()

sns.heatmap(pd.crosstab(review_1078['Text Length'], review_1078['Rating'],normalize = 'columns'),
            annot=True, linewidths=.5, ax=ax[1], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})

# %% [markdown]
# ## Size and Price

# %%
def select_string(s,sel):
    if pd.isnull(s):
        return False
    else:
        if any(sel_w in s.lower().split() for sel_w in sel):
            return True
        else:
            return False

# %%
review_price=data[data['Review Text'].apply(lambda x: select_string(x,['price','cheap','money','expensive']))]

# %%
print(word_freq(review_price['Review Text']).most_common(100))
# Out:
# [('price', 715), ('dress', 488), ('like', 381), ('love', 340), ('top', 318), ('fit', 299), ('would', 287), ('size', 285), ('sale', 256), ('fabric', 255), ('wear', 254), ('great', 250), ('cheap', 228), ('look', 213), ('quality', 190), ('color', 187), ('one', 182), ('material', 171), ('really', 169), ('worth', 168), ('back', 165), ('much', 160), ('cute', 160), ('little', 156), ('small', 154), ('full', 153), ('well', 150), ('looks', 147), ('ordered', 142), ('retailer', 141), ('even', 136), ('store', 134), ('shirt', 134), ('got', 132), ('bought', 131), ('perfect', 130), ('also', 126), ('bit', 125), ('think', 123), ('nice', 119), ('flattering', 114), ('beautiful', 114), ('jeans', 114), ('high', 112), ('could', 111), ('fits', 108), ('thin', 107), ('made', 105), ('see', 105), ('sweater', 103), ('colors', 101), ('pretty', 100), ('soft', 99), ('length', 96), ('good', 96), ('black', 96), ('way', 95), ('expensive', 94), ('online', 93), ('large', 91), ('point', 90), ('still', 87), ('long', 86), 
# ...

# %%
review_price['Review Text'][2]
# Out:
# 'I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c'

# %%
text = nltk.tokenize.word_tokenize(review_price['Review Text'][2])
#nltk.pos_tag(text)                  # only look for nouns and adjs

# %%
pd.isnull(data['Review Text'][92])
# Out:
# True

# %%
#sns.lmplot(x='Text Length',y='Rating',data=review_1078)

# %%
#top_N = 20 
#print('All frequencies:')
#print('=' * 60)
#rslt = pd.DataFrame(words_dist_title.most_common(top_N),
#                    columns=['Word', 'Frequency'])
#print(rslt)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=text_process).fit(title) # convert to matrix

# %%
print(len(bow_transformer.vocabulary_)) # total number of vocabulary
# Out:
# 4913

# %%
messages_bow = bow_transformer.transform(title)

# %%
print('Shape of Sparse Matrix: ', messages_bow.shape)
# Out:
# Shape of Sparse Matrix:  (19676, 4913)

# %%
sparsity = (100.0*messages_bow.nnz/(messages_bow.shape[0]*messages_bow.shape[1]))
print('sparsity:{}'.format(sparsity))
# Out:
# sparsity:0.04864268274067576

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(messages_bow)

# %%
messages_tfidf = tfidf_transformer.transform(messages_bow)

# %%
X=data['']

# %%
#data.groupby(['Rating','Recommended IND']).mean()['Positive Feedback Count']
f, ax = plt.subplots(1, 3, figsize=(18, 7))
fsize = 13
sns.heatmap(pd.crosstab(data['Division Name'],data['Rating'],normalize = 'index'),
            annot=True, linewidths=.5, ax=ax[0], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})

sns.heatmap(pd.crosstab( data['Department Name'],data['Rating'],normalize = 'index'),
            annot=True, linewidths=.5, ax=ax[1], fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'})


sns.heatmap(pd.crosstab(data['Class Name'],data['Rating'],normalize = 'index'),
            annot=True, linewidths=.5, fmt='g', cmap='Oranges',
            cbar_kws={'label': 'Count'},ax=ax[2])
